# %%
# Question 1
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('weather.csv')

# %%
print(data.head())
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
print(data.shape)
# Out:
# (366, 24)

# %%
print(data.describe())
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
sns.distplot(data['Cloud3pm'],kde=False)

# %%
sns.distplot(data['Cloud3pm'],hist=False)

# %%
sns.distplot(data['MaxTemp'],kde=False)

# %%
sns.distplot(data['MaxTemp'],hist=False)

# %%
data['Sunshine'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 336    False
# 337    False
# 338    False
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# 344    False
# 345    False
# 346    False
# 347    False
# 348     True
# 349    False
# 350    False
# 351    False
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# 357    False
# 358    False
# 359    False
# 360    False
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: Sunshine, Length: 366, dtype: bool

# %%
data['Sunshine']=data['Sunshine'].fillna(data['Sunshine'].mean())

# %%
print(data['Sunshine'])
# Out:
# 0       6.300000
# 1       9.700000
# 2       3.300000
# 3       9.100000
# 4      10.600000
# 5       8.200000
# 6       8.400000
# 7       4.600000
# 8       4.100000
# 9       7.700000
# 10     11.900000
# 11     12.500000
# 12     13.000000
# 13     12.400000
# 14     13.100000
# 15     11.100000
# 16      8.400000
# 17     10.100000
# 18     13.000000
# 19     10.400000
# 20      9.500000
# 21      0.000000
# 22      0.600000
# 23      7.500000
# 24      8.100000
# 25      8.900000
# 26      2.300000
# 27     10.700000
# 28      0.400000
# 29      0.500000
#          ...
# 336    11.000000
# 337    10.800000
# 338     4.900000
# 339     6.700000
# 340     8.400000
# 341    11.800000
# 342    11.500000
# 343    11.500000
# 344    11.000000
# 345    11.200000
# 346    11.700000
# 347     7.500000
# 348     7.909366
# 349    10.400000
# 350    12.200000
# 351    12.000000
# 352     8.600000
# 353     9.800000
# 354    12.100000
# 355     6.200000
# 356    11.700000
# ...

# %%
sns.kdeplot(data['Sunshine'])

# %%
print(data.head())
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.jointplot(x='Rainfall',y='Evaporation',data=data)

# %%
sns.jointplot(x='Evaporation',y='Rainfall',data=data)

# %%
with sns.axes_style("white"):
    sns.jointplot(x='Evaporation',y='Rainfall',kind='hex',color='k',data=data)

# %%
sns.jointplot(x='Evaporation',y='Rainfall',kind='kde',color='k',data=data)

# %%
print(data.head())
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
sns.stripplot(x='RainToday',y='Cloud9am',data=data,jitter=True)

# %%
sns.swarmplot(x='RainToday',y='Cloud9am',data=data)

# %%
sns.boxplot(x='RainToday',y='Cloud9am',data=data)

# %%
sns.countplot(x='RainToday',palette="Greens_d",data=data)

# %%
print(data.describe(include='all'))
# Out:
#              Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count         366       366  366.000000  366.000000  366.000000   366.000000
# unique        366         1         NaN         NaN         NaN          NaN
# top     11/8/2007  Canberra         NaN         NaN         NaN          NaN
# freq            1       366         NaN         NaN         NaN          NaN
# mean          NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std           NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min           NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%           NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%           NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%           NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max           NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
sns.stripplot(x='WindDir9am',y='Cloud9am',data=data)

# %%
sns.swarmplot(x='WindDir9am',y='Cloud9am',data=data)

# %%
 sns.pointplot(x="MaxTemp", y="MinTemp", data=data, capsize=.2)
